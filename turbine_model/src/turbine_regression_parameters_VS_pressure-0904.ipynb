# %%
import os
import sys
import numpy as np
import pandas as pd 
from matplotlib import pyplot as plt
from turbine_regression import get_origin_data
from turbine_regression import data_preprocessing
from turbine_regression import get_result_data

# %% [markdown]
# ## 压力平均数据

# %%
origin_data = get_origin_data(period = 2)
origin_data = origin_data[[
    "eturb_m1_steam_pressure_in", "eturb_m2_steam_pressure_in", "bturb_m1_steam_pressure_in",
    "eturb_m1_steam_temperature_in", "eturb_m2_steam_temperature_in", "bturb_m1_steam_temperature_in",
    "eturb_m1_steam_pressure_side", "eturb_m2_steam_pressure_side", "bturb_m1_steam_pressure_out",
    "eturb_m1_steam_temperature_side", "eturb_m2_steam_temperature_side", "eturb_m1_steam_temperature_out",
    "eturb_m1_steam_pressure_out", "eturb_m2_steam_pressure_out", 
    "eturb_m1_steam_temperature_out", "eturb_m2_steam_temperature_out",
]]
origin_df = data_preprocessing(origin_data, method = "mean", is_export_csv = 0).reset_index(drop = True)
origin_df
# Out:
#      eturb_m1_steam_pressure_in  eturb_m2_steam_pressure_in  \
# 0                      2.999978                    3.016606
# 1                      2.993508                    3.010711
# 2                      2.983609                    3.001691
# 3                      2.965462                    2.983511
# 4                      2.951569                    2.969450
# ..                          ...                         ...
# 134                    3.282394                    3.284815
# 135                    3.283514                    3.285034
# 136                    3.285881                    3.286841
# 137                    3.280038                    3.280283
# 138                    3.274543                    3.275084
#
#      bturb_m1_steam_pressure_in  eturb_m1_steam_temperature_in  \
# 0                      3.033013                     426.836683
# 1                      3.026984                     426.733553
# ...

# %% [markdown]
# ## 回归结果

# %%
result_df = get_result_data(period = 2)
result_df_origin = result_df[["eturb_m1_origin_k1", "eturb_m1_origin_k2", "eturb_m2_origin_k1", "bturb_m1_origin_k1"]].reset_index(drop = True)
result_df_delta = result_df[["eturb_m1_delta_k1", "eturb_m1_delta_k2", "eturb_m2_delta_k1", "bturb_m1_delta_k1"]].reset_index(drop = True)
result_df_base = result_df[["eturb_m1_base_k1", "eturb_m1_base_k2", "eturb_m2_base_k1", "bturb_m1_base_k1"]].reset_index(drop = True)
result_df_origin
# Out:
#      eturb_m1_origin_k1  eturb_m1_origin_k2  eturb_m2_origin_k1  \
# 0              0.164106           -0.090118            0.078791
# 1              0.159864           -0.092924            0.090889
# 2              0.164130           -0.084858            0.094891
# 3              0.167433           -0.089714            0.101018
# 4              0.174524           -0.100509            0.099602
# ..                  ...                 ...                 ...
# 134            0.121939           -0.072253            0.177981
# 135            0.135752           -0.074320            0.174610
# 136            0.124805           -0.062121            0.168684
# 137            0.144547           -0.072109            0.166971
# 138            0.161864           -0.086159            0.172850
#
#      bturb_m1_origin_k1
# 0              0.060755
# 1              0.062971
# 2              0.060334
# 3              0.046776
# 4              0.041426
# ..                  ...
# ...

# %%
result_df_delta
# Out:
#      eturb_m1_delta_k1  eturb_m1_delta_k2  eturb_m2_delta_k1  \
# 0             0.138334          -0.086428           0.096897
# 1             0.142827          -0.092328           0.092936
# 2             0.140119          -0.061259           0.112507
# 3             0.149310          -0.058573           0.116170
# 4             0.150725          -0.057400           0.117756
# ..                 ...                ...                ...
# 134           0.076697          -0.015485           0.166835
# 135           0.073684          -0.007115           0.167613
# 136           0.080347          -0.016525           0.168686
# 137           0.087765          -0.003570           0.170259
# 138           0.083629           0.005791           0.168935
#
#      bturb_m1_delta_k1
# 0             0.060834
# 1             0.061375
# 2             0.061512
# 3             0.059220
# 4             0.057821
# ..                 ...
# 134           0.082427
# 135           0.082400
# ...

# %%
result_df_base
# Out:
#      eturb_m1_base_k1  eturb_m1_base_k2  eturb_m2_base_k1  bturb_m1_base_k1
# 0            0.176585         -0.086499          0.065688          0.067261
# 1            0.177235         -0.117799          0.139546          0.072405
# 2            0.164373         -0.084977          0.091620          0.078237
# 3            0.168880         -0.088303          0.039867          0.040424
# 4            0.167091         -0.089820          0.098110          0.058896
# ..                ...               ...               ...               ...
# 134          0.129917         -0.075354          0.173960          0.127428
# 135          0.126750         -0.077771          0.186004          0.190529
# 136          0.155849         -0.084265          0.186004          0.162406
# 137          0.144043         -0.070321          0.170153          0.209423
# 138          0.161792         -0.084960          0.163251          0.163264
#
# [139 rows x 4 columns]

# %%
# Origin k1、k2
df_origin = pd.concat([result_df_origin, origin_df], axis = 1, sort = False)
df_origin.head()
# Out:
#    eturb_m1_origin_k1  eturb_m1_origin_k2  eturb_m2_origin_k1  \
# 0            0.164106           -0.090118            0.078791
# 1            0.159864           -0.092924            0.090889
# 2            0.164130           -0.084858            0.094891
# 3            0.167433           -0.089714            0.101018
# 4            0.174524           -0.100509            0.099602
#
#    bturb_m1_origin_k1  eturb_m1_steam_pressure_in  eturb_m2_steam_pressure_in  \
# 0            0.060755                    2.999978                    3.016606
# 1            0.062971                    2.993508                    3.010711
# 2            0.060334                    2.983609                    3.001691
# 3            0.046776                    2.965462                    2.983511
# 4            0.041426                    2.951569                    2.969450
#
#    bturb_m1_steam_pressure_in  eturb_m1_steam_temperature_in  \
# ...

# %%
# Delta k1、k2
df_delta = pd.concat([result_df_delta, origin_df], axis = 1, sort = False)
df_delta.head()
# Out:
#    eturb_m1_delta_k1  eturb_m1_delta_k2  eturb_m2_delta_k1  bturb_m1_delta_k1  \
# 0           0.138334          -0.086428           0.096897           0.060834
# 1           0.142827          -0.092328           0.092936           0.061375
# 2           0.140119          -0.061259           0.112507           0.061512
# 3           0.149310          -0.058573           0.116170           0.059220
# 4           0.150725          -0.057400           0.117756           0.057821
#
#    eturb_m1_steam_pressure_in  eturb_m2_steam_pressure_in  \
# 0                    2.999978                    3.016606
# 1                    2.993508                    3.010711
# 2                    2.983609                    3.001691
# 3                    2.965462                    2.983511
# 4                    2.951569                    2.969450
#
#    bturb_m1_steam_pressure_in  eturb_m1_steam_temperature_in  \
# 0                    3.033013                     426.836683
# ...

# %%
# Base k1、 k2
df_base = pd.concat([result_df_base, origin_df], axis = 1, sort = False)
df_base.head()
# Out:
#    eturb_m1_base_k1  eturb_m1_base_k2  eturb_m2_base_k1  bturb_m1_base_k1  \
# 0          0.176585         -0.086499          0.065688          0.067261
# 1          0.177235         -0.117799          0.139546          0.072405
# 2          0.164373         -0.084977          0.091620          0.078237
# 3          0.168880         -0.088303          0.039867          0.040424
# 4          0.167091         -0.089820          0.098110          0.058896
#
#    eturb_m1_steam_pressure_in  eturb_m2_steam_pressure_in  \
# 0                    2.999978                    3.016606
# 1                    2.993508                    3.010711
# 2                    2.983609                    3.001691
# 3                    2.965462                    2.983511
# 4                    2.951569                    2.969450
#
#    bturb_m1_steam_pressure_in  eturb_m1_steam_temperature_in  \
# 0                    3.033013                     426.836683
# ...

# %% [markdown]
# # eturb_m1

# %%
fig, axs = plt.subplots(figsize = (20, 5), sharey = True, tight_layout = True)
plt.subplot(1, 3, 1)
result_df["eturb_m1_origin_k1"].plot(kind = "hist", bins = 20, color = "steelblue", edgecolor = "black", density = True, label = "Histogram")
result_df["eturb_m1_origin_k1"].plot(kind = "kde", color = "red", label = "KDE")
plt.xlabel("eturb_m1_origin_k1")
plt.ylabel("Count")
plt.title("eturb_m1_origin_k1")
plt.legend()
plt.subplot(1, 3, 2)
result_df["eturb_m1_origin_k2"].plot(kind = "hist", bins = 20, color = "steelblue", edgecolor = "black", density = True, label = "Histogram")
result_df["eturb_m1_origin_k2"].plot(kind = "kde", color = "red", label = "KDE")
plt.xlabel("eturb_m1_origin_k2")
plt.ylabel("Count")
plt.title("eturb_m1_origin_k2")
plt.legend()
plt.subplot(1, 3, 3)
result_df["eturb_m1_origin_R2"].plot(kind = "hist", bins = 20, color = "steelblue", edgecolor = "black", density = True, label = "Histogram")
result_df["eturb_m1_origin_R2"].plot(kind = "kde", color = "red", label = "KDE")
plt.xlabel("eturb_m1_origin_R2")
plt.ylabel("Count")
plt.title("eturb_m1_origin_R2")
plt.legend()
plt.show()

# %%
fig, axs = plt.subplots(figsize = (20, 5), sharey = True, tight_layout = True)
plt.subplot(1, 3, 1)
result_df["eturb_m1_delta_k1"].plot(kind = "hist", bins = 20, color = "steelblue", edgecolor = "black", density = True, label = "Histogram")
result_df["eturb_m1_delta_k1"].plot(kind = "kde", color = "red", label = "KDE")
plt.xlabel("eturb_m1_delta_k1")
plt.ylabel("Count")
plt.title("eturb_m1_delta_k1")
plt.legend()
plt.subplot(1, 3, 2)
result_df["eturb_m1_delta_k2"].plot(kind = "hist", bins = 20, color = "steelblue", edgecolor = "black", density = True, label = "Histogram")
result_df["eturb_m1_delta_k2"].plot(kind = "kde", color = "red", label = "KDE")
plt.xlabel("eturb_m1_delta_k2")
plt.ylabel("Count")
plt.title("eturb_m1_delta_k2")
plt.legend()
plt.subplot(1, 3, 3)
result_df["eturb_m1_delta_R2"].plot(kind = "hist", bins = 20, color = "steelblue", edgecolor = "black", density = True, label = "Histogram")
result_df["eturb_m1_delta_R2"].plot(kind = "kde", color = "red", label = "KDE")
plt.xlabel("eturb_m1_delta_R2")
plt.ylabel("Count")
plt.title("eturb_m1_delta_R2")
plt.legend()
plt.show()

# %%
fig, axs = plt.subplots(figsize = (20, 5), sharey = True, tight_layout = True)
plt.subplot(1, 3, 1)
result_df["eturb_m1_base_k1"].plot(kind = "hist", bins = 20, color = "steelblue", edgecolor = "black", density = True, label = "Histogram")
result_df["eturb_m1_base_k1"].plot(kind = "kde", color = "red", label = "KDE")
plt.xlabel("eturb_m1_base_k1")
plt.ylabel("Count")
plt.title("eturb_m1_base_k1")
plt.legend()
plt.subplot(1, 3, 2)
result_df["eturb_m1_base_k2"].plot(kind = "hist", bins = 20, color = "steelblue", edgecolor = "black", density = True, label = "Histogram")
result_df["eturb_m1_base_k2"].plot(kind = "kde", color = "red", label = "KDE")
plt.xlabel("eturb_m1_base_k2")
plt.ylabel("Count")
plt.title("eturb_m1_base_k2")
plt.legend()
plt.subplot(1, 3, 3)
result_df["eturb_m1_base_R2"].plot(kind = "hist", bins = 20, color = "steelblue", edgecolor = "black", density = True, label = "Histogram")
result_df["eturb_m1_base_R2"].plot(kind = "kde", color = "red", label = "KDE")
plt.xlabel("eturb_m1_base_R2")
plt.ylabel("Count")
plt.title("eturb_m1_base_R2")
plt.legend()
plt.show()

# %%
fig, axs = plt.subplots(figsize = (20, 5))
plt.subplot(1, 3, 1)
plt.scatter(df_origin["eturb_m1_steam_pressure_in"], df_origin["eturb_m1_origin_k1"])
plt.title("[Origin Method]1# Turbine steam_pressure_in VS k1")
plt.xlabel("steam_pressure_in")
plt.ylabel("k1")
plt.subplot(1, 3, 2)
plt.scatter(df_delta["eturb_m1_steam_pressure_in"], df_delta["eturb_m1_delta_k1"])
plt.title("[Delta Method]1# Turbine steam_pressure_in VS k1")
plt.xlabel("steam_pressure_in")
plt.ylabel("k1")
plt.subplot(1, 3, 3)
plt.scatter(df_base["eturb_m1_steam_pressure_in"], df_base["eturb_m1_base_k1"])
plt.title("[Base Method]1# Turbine steam_pressure_in VS k1")
plt.xlabel("steam_pressure_in")
plt.ylabel("k1")
plt.show()

# %%
fig, axs = plt.subplots(figsize = (20, 5))
plt.subplot(1, 3, 1)
plt.scatter(df_origin["eturb_m1_steam_pressure_side"], df_origin["eturb_m1_origin_k2"])
plt.title("[Origin Method]1# Turbine steam_pressure_side VS k2")
plt.xlabel("steam_pressure_side")
plt.ylabel("k2")
plt.subplot(1, 3, 2)
plt.scatter(df_delta["eturb_m1_steam_pressure_side"], df_delta["eturb_m1_delta_k2"])
plt.title("[Delta Method]1# Turbine steam_pressure_side VS k2")
plt.xlabel("steam_pressure_side")
plt.ylabel("k2")
plt.subplot(1, 3, 3)
plt.scatter(df_base["eturb_m1_steam_pressure_side"], df_base["eturb_m1_base_k2"])
plt.title("[Base Method]1# Turbine steam_pressure_side VS k2")
plt.xlabel("steam_pressure_side")
plt.ylabel("k2")
plt.show()

# %% [markdown]
# # eturb_m2

# %%
fig, axs = plt.subplots(figsize = (20, 5), sharey = True, tight_layout = True)
plt.subplot(1, 2, 1)
result_df["eturb_m2_origin_k1"].plot(kind = "hist", bins = 20, color = "steelblue", edgecolor = "black", density = True, label = "Histogram")
result_df["eturb_m2_origin_k1"].plot(kind = "kde", color = "red", label = "KDE")
plt.xlabel("eturb_m2_origin_k1")
plt.ylabel("Count")
plt.title("eturb_m2_origin_k1")
plt.legend()
plt.subplot(1, 2, 2)
result_df["eturb_m2_origin_R2"].plot(kind = "hist", bins = 20, color = "steelblue", edgecolor = "black", density = True, label = "Histogram")
result_df["eturb_m2_origin_R2"].plot(kind = "kde", color = "red", label = "KDE")
plt.xlabel("eturb_m2_origin_R2")
plt.ylabel("Count")
plt.title("eturb_m2_origin_R2")
plt.legend()
plt.show()

# %%
fig, axs = plt.subplots(figsize = (20, 5), sharey = True, tight_layout = True)
plt.subplot(1, 2, 1)
result_df["eturb_m2_delta_k1"].plot(kind = "hist", bins = 20, color = "steelblue", edgecolor = "black", density = True, label = "Histogram")
result_df["eturb_m2_delta_k1"].plot(kind = "kde", color = "red", label = "KDE")
plt.xlabel("eturb_m2_delta_k1")
plt.ylabel("Count")
plt.title("eturb_m2_delta_k1")
plt.legend()
plt.subplot(1, 2, 2)
result_df["eturb_m2_delta_R2"].plot(kind = "hist", bins = 20, color = "steelblue", edgecolor = "black", density = True, label = "Histogram")
result_df["eturb_m2_delta_R2"].plot(kind = "kde", color = "red", label = "KDE")
plt.xlabel("eturb_m2_delta_R2")
plt.ylabel("Count")
plt.title("eturb_m2_delta_R2")
plt.legend()
plt.show()

# %%
fig, axs = plt.subplots(figsize = (20, 5), sharey = True, tight_layout = True)
plt.subplot(1, 2, 1)
result_df["eturb_m2_base_k1"].plot(kind = "hist", bins = 20, color = "steelblue", edgecolor = "black", density = True, label = "Histogram")
result_df["eturb_m2_base_k1"].plot(kind = "kde", color = "red", label = "KDE")
plt.xlabel("eturb_m2_base_k1")
plt.ylabel("Count")
plt.title("eturb_m2_base_k1")
plt.legend()
plt.subplot(1, 2, 2)
result_df["eturb_m2_base_R2"].plot(kind = "hist", bins = 20, color = "steelblue", edgecolor = "black", density = True, label = "Histogram")
result_df["eturb_m2_base_R2"].plot(kind = "kde", color = "red", label = "KDE")
plt.xlabel("eturb_m2_base_R2")
plt.ylabel("Count")
plt.title("eturb_m2_base_R2")
plt.legend()
plt.show()

# %%
fig, axs = plt.subplots(figsize = (20, 5))
plt.subplot(1, 3, 1)
plt.scatter(df_origin["eturb_m2_steam_pressure_in"], df_origin["eturb_m2_origin_k1"])
plt.title("[Origin Method]1# Turbine steam_pressure_in VS k1")
plt.xlabel("steam_pressure_in")
plt.ylabel("k1")
plt.subplot(1, 3, 2)
plt.scatter(df_delta["eturb_m2_steam_pressure_in"], df_delta["eturb_m2_delta_k1"])
plt.title("[Delta Method]1# Turbine steam_pressure_in VS k1")
plt.xlabel("steam_pressure_in")
plt.ylabel("k1")
plt.subplot(1, 3, 3)
plt.scatter(df_base["eturb_m2_steam_pressure_in"], df_base["eturb_m2_base_k1"])
plt.title("[Base Method]1# Turbine steam_pressure_in VS k1")
plt.xlabel("steam_pressure_in")
plt.ylabel("k1")
plt.show()

# %% [markdown]
# # bturb_m1

# %%
fig, axs = plt.subplots(figsize = (20, 5), sharey = True, tight_layout = True)
plt.subplot(1, 2, 1)
result_df["bturb_m1_origin_k1"].plot(kind = "hist", bins = 20, color = "steelblue", edgecolor = "black", density = True, label = "Histogram")
result_df["bturb_m1_origin_k1"].plot(kind = "kde", color = "red", label = "KDE")
plt.xlabel("bturb_m1_origin_k1")
plt.ylabel("Count")
plt.title("bturb_m1_origin_k1")
plt.legend()
plt.subplot(1, 2, 2)
result_df["bturb_m1_origin_R2"].plot(kind = "hist", bins = 20, color = "steelblue", edgecolor = "black", density = True, label = "Histogram")
result_df["bturb_m1_origin_R2"].plot(kind = "kde", color = "red", label = "KDE")
plt.xlabel("bturb_m1_origin_R2")
plt.ylabel("Count")
plt.title("bturb_m1_origin_R2")
plt.legend()
plt.show()

# %%
fig, axs = plt.subplots(figsize = (20, 5), sharey = True, tight_layout = True)
plt.subplot(1, 2, 1)
result_df["bturb_m1_delta_k1"].plot(kind = "hist", bins = 20, color = "steelblue", edgecolor = "black", density = True, label = "Histogram")
result_df["bturb_m1_delta_k1"].plot(kind = "kde", color = "red", label = "KDE")
plt.xlabel("bturb_m1_delta_k1")
plt.ylabel("Count")
plt.title("bturb_m1_delta_k1")
plt.legend()
plt.subplot(1, 2, 2)
result_df["bturb_m1_delta_R2"].plot(kind = "hist", bins = 20, color = "steelblue", edgecolor = "black", density = True, label = "Histogram")
result_df["bturb_m1_delta_R2"].plot(kind = "kde", color = "red", label = "KDE")
plt.xlabel("bturb_m1_delta_R2")
plt.ylabel("Count")
plt.title("bturb_m1_delta_R2")
plt.legend()
plt.show()

# %%
fig, axs = plt.subplots(figsize = (20, 5), sharey = True, tight_layout = True)
plt.subplot(1, 2, 1)
result_df["bturb_m1_base_k1"].plot(kind = "hist", bins = 20, color = "steelblue", edgecolor = "black", density = True, label = "Histogram")
result_df["bturb_m1_base_k1"].plot(kind = "kde", color = "red", label = "KDE")
plt.xlabel("bturb_m1_base_k1")
plt.ylabel("Count")
plt.title("bturb_m1_base_k1")
plt.legend()
plt.subplot(1, 2, 2)
result_df["bturb_m1_base_R2"].plot(kind = "hist", bins = 20, color = "steelblue", edgecolor = "black", density = True, label = "Histogram")
result_df["bturb_m1_base_R2"].plot(kind = "kde", color = "red", label = "KDE")
plt.xlabel("bturb_m1_base_R2")
plt.ylabel("Count")
plt.title("bturb_m1_base_R2")
plt.legend()
plt.show()

# %%
fig, axs = plt.subplots(figsize = (20, 5))
plt.subplot(1, 3, 1)
plt.scatter(df_origin["bturb_m1_steam_pressure_in"], df_origin["bturb_m1_origin_k1"])
plt.title("[Origin Method]1# Turbine steam_pressure_in VS k1")
plt.xlabel("steam_pressure_in")
plt.ylabel("k1")
plt.subplot(1, 3, 2)
plt.scatter(df_delta["bturb_m1_steam_pressure_in"], df_delta["bturb_m1_delta_k1"])
plt.title("[Delta Method]1# Turbine steam_pressure_in VS k1")
plt.xlabel("steam_pressure_in")
plt.ylabel("k1")
plt.subplot(1, 3, 3)
plt.scatter(df_base["bturb_m1_steam_pressure_in"], df_base["bturb_m1_base_k1"])
plt.title("[Base Method]1# Turbine steam_pressure_in VS k1")
plt.xlabel("steam_pressure_in")
plt.ylabel("k1")
plt.show()
